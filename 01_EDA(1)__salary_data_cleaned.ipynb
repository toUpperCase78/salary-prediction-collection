# %% [markdown]
# # 01. PlayingNumbers/ds_salary_proj
#
# ## Exploratory Data Analysis | Series 1 - salary_data_cleaned.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary_data = pd.read_csv('01_salary_data_cleaned.csv')

# %%
salary_data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# ...

# %%
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  hourly             742 non-null    int64
#  15  employer_provided  742 non-null    int64
# ...

# %%
salary_data.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %% [markdown]
# ## Histograms

# %%
# Excluded 11 ratings that are equal to -1
plt.hist(salary_data[salary_data['Rating'] != -1.0]['Rating'], bins=32, zorder=2)  
plt.title("Company Ratings", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %%
# Excluded 50 values that are equal to -1
plt.hist(salary_data[salary_data['Founded'] != -1]['Founded'], bins=100, zorder=2)
plt.title("Company Founded Years", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %%
# Excluded 50 values that are equal to -1
plt.hist(salary_data[salary_data['age'] != -1]['age'], bins=100, zorder=2)
plt.title("Company Ages", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %%
plt.hist(salary_data['min_salary'], bins=100, zorder=2)
plt.title("Minimum Salaries", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %%
plt.hist(salary_data['max_salary'], bins=100, zorder=2)
plt.title("Maximum Salaries", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %%
plt.hist(salary_data['avg_salary'], bins=100, zorder=2)
plt.title("Average Salaries", fontsize=16)
plt.grid(axis='y', color='#dddddd', zorder=1)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.scatter(salary_data[salary_data['Rating'] != -1.0]['Rating'], 
            salary_data[salary_data['Rating'] != -1.0]['avg_salary'], s=20, alpha=0.5)
plt.title("Company Rating vs Avg Salary\n-1.0 Ratings Removed")
plt.grid(color='#dddddd')
plt.show()

# %%
plt.scatter(salary_data[salary_data['Founded'] != -1]['Founded'], 
            salary_data[salary_data['Founded'] != -1]['avg_salary'], s=20, alpha=0.5)
plt.title("Company Founded Year vs Avg Salary\n-1 Founded Years Removed")
plt.grid(color="#dddddd")
plt.show()

# %%
plt.scatter(salary_data[salary_data['age'] != -1]['age'], 
            salary_data[salary_data['age'] != -1]['avg_salary'], s=20, alpha=0.5)
plt.title("Company Age vs Avg Salary\n-1 Ages Removed")
plt.grid(color="#dddddd")
plt.show()

# %% [markdown]
# ## Counts of Binary Values

# %%
salary_data['hourly'].value_counts()
# Out:
# 0    718
# 1     24
# Name: hourly, dtype: int64

# %%
salary_data['employer_provided'].value_counts()
# Out:
# 0    725
# 1     17
# Name: employer_provided, dtype: int64

# %%
salary_data['same_state'].value_counts()
# Out:
# 1    414
# 0    328
# Name: same_state, dtype: int64

# %%
salary_data['python_yn'].value_counts()
# Out:
# 1    392
# 0    350
# Name: python_yn, dtype: int64

# %%
salary_data['R_yn'].value_counts()
# Out:
# 0    740
# 1      2
# Name: R_yn, dtype: int64

# %%
salary_data['spark'].value_counts()
# Out:
# 0    575
# 1    167
# Name: spark, dtype: int64

# %%
salary_data['aws'].value_counts()
# Out:
# 0    566
# 1    176
# Name: aws, dtype: int64

# %%
salary_data['excel'].value_counts()
# Out:
# 1    388
# 0    354
# Name: excel, dtype: int64

# %% [markdown]
# ## Explorations on Textual Values

# %%
print("#### COUNTS OF JOB STATES ####")
salary_data['job_state']= salary_data['job_state'].apply(
    lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
print(salary_data['job_state'].value_counts())
# Out:
# #### COUNTS OF JOB STATES ####
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
print(salary_data['Job Title'].nunique(), "unique job titles")
print("\n#### COUNTS OF JOB STATES ####")
print(salary_data['Job Title'].value_counts()[:20])
# Out:
# 264 unique job titles
#
# #### COUNTS OF JOB STATES ####
# Data Scientist                                    131
# Data Engineer                                      53
# Senior Data Scientist                              34
# Data Analyst                                       15
# Senior Data Engineer                               14
# Senior Data Analyst                                12
# Lead Data Scientist                                 8
# Marketing Data Analyst                              6
# Sr. Data Engineer                                   6
# Machine Learning Engineer                           5
# Principal Data Scientist                            5
# R&D Specialist/ Food Scientist                      4
# Medical Laboratory Scientist                        4
# Research Scientist                                  4
# Senior Research Scientist-Machine Learning          4
# MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB           4
# ...

# %%
print(salary_data['Company Name'].nunique(), "unique company names")
print("\n#### COUNTS OF COMPANY NAMES ####")
print(salary_data['Company Name'].value_counts()[:20])
# Out:
# 343 unique company names
#
# #### COUNTS OF COMPANY NAMES ####
# MassMutual\r\n3.6                                         14
# Reynolds American\r\n3.1                                  14
# Takeda Pharmaceuticals\r\n3.7                             14
# Software Engineering Institute\r\n2.6                     11
# PNNL\r\n3.8                                               10
# Liberty Mutual Insurance\r\n3.3                           10
# AstraZeneca\r\n3.9                                         9
# MITRE\r\n3.2                                               8
# Numeric, LLC\r\n3.2                                        7
# Advanced BioScience Laboratories\r\n2.7                    7
# Fareportal\r\n3.8                                          7
# Pfizer\r\n4.0                                              7
# Novartis\r\n3.8                                            7
# Rochester Regional Health\r\n3.3                           7
# ...

# %%
print(salary_data['company_txt'].nunique(), "unique company texts")
print("\n#### COUNTS OF COMPANY TEXTS ####")
print(salary_data['company_txt'].value_counts()[:20])
# Out:
# 343 unique company texts
#
# #### COUNTS OF COMPANY TEXTS ####
# MassMutual\r\n                                         14
# Reynolds American\r\n                                  14
# Takeda Pharmaceuticals\r\n                             14
# Software Engineering Institute\r\n                     11
# PNNL\r\n                                               10
# Liberty Mutual Insurance\r\n                           10
# AstraZeneca\r\n                                         9
# MITRE\r\n                                               8
# Numeric, LLC\r\n                                        7
# Advanced BioScience Laboratories\r\n                    7
# Fareportal\r\n                                          7
# Pfizer\r\n                                              7
# Novartis\r\n                                            7
# Rochester Regional Health\r\n                           7
# Novetta\r\n                                             6
# ...

# %%
print(salary_data['Location'].nunique(), "unique locations")
print("\n#### COUNTS OF LOCATIONS ####")
print(salary_data['Location'].value_counts()[:20])
# Out:
# 200 unique locations
#
# #### COUNTS OF LOCATIONS ####
# New York, NY               55
# San Francisco, CA          49
# Cambridge, MA              47
# Chicago, IL                32
# Boston, MA                 23
# San Jose, CA               13
# Pittsburgh, PA             12
# Washington, DC             11
# Rockville, MD              11
# Winston-Salem, NC          10
# Richland, WA               10
# Herndon, VA                10
# Indianapolis, IN            9
# San Diego, CA               9
# Mountain View, CA           8
# Austin, TX                  8
# South San Francisco, CA     8
# Rochester, NY               7
# Palo Alto, CA               7
# Salt Lake City, UT          6
# Name: Location, dtype: int64

# %%
print(salary_data['Headquarters'].nunique(), "unique headquarters")
print("\n#### COUNTS OF HEADQUARTERS ####")
print(salary_data['Headquarters'].value_counts()[:20])
# Out:
# 198 unique headquarters
#
# #### COUNTS OF HEADQUARTERS ####
# New York, NY                 52
# San Francisco, CA            42
# Chicago, IL                  30
# Cambridge, MA                20
# Springfield, MA              14
# Boston, MA                   14
# Winston-Salem, NC            14
# OSAKA, Japan                 14
# Richland, WA                 12
# Reston, VA                   12
# Mountain View, CA            11
# Pittsburgh, PA               11
# Palo Alto, CA                10
# Washington, DC                9
# Cambridge, United Kingdom     9
# Salt Lake City, UT            9
# Denver, CO                    8
# Rockville, MD                 8
# San Jose, CA                  8
# Bedford, MA                   8
# Name: Headquarters, dtype: int64

# %%
print("#### COMPANY SIZES ####")
print(salary_data['Size'].value_counts())
# Out:
# #### COMPANY SIZES ####
# 1001 to 5000 employees     150
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# Unknown                      9
# -1                           1
# Name: Size, dtype: int64

# %%
print("#### TYPES OF OWNERSHIP ####")
print(salary_data['Type of ownership'].value_counts())
# Out:
# #### TYPES OF OWNERSHIP ####
# Company - Private                 410
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  3
# School / School District            2
# Unknown                             1
# -1                                  1
# Name: Type of ownership, dtype: int64

# %%
print(salary_data['Industry'].nunique(), "unique industries")
print("\n#### COUNTS OF INDUSTRIES ####")
print(salary_data['Industry'].value_counts())
# Out:
# 60 unique industries
#
# #### COUNTS OF INDUSTRIES ####
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# -1                                           10
# Staffing & Outsourcing                       10
# ...

# %%
print(salary_data['Sector'].nunique(), "unique sectors")
print("\n#### COUNTS OF SECTORS ####")
print(salary_data['Sector'].value_counts())
# Out:
# 25 unique sectors
#
# #### COUNTS OF SECTORS ####
# Information Technology                180
# Biotech & Pharmaceuticals             112
# Business Services                      97
# Insurance                              69
# Health Care                            49
# Finance                                42
# Manufacturing                          34
# Aerospace & Defense                    25
# Education                              23
# Retail                                 15
# Oil, Gas, Energy & Utilities           14
# Government                             11
# -1                                     10
# Non-Profit                              9
# Transportation & Logistics              8
# Real Estate                             8
# Travel & Tourism                        8
# Telecommunications                      6
# Media                                   6
# Arts, Entertainment & Recreation        4
# Consumer Services                       4
# ...

# %%
print("#### REVENUES ####")
print(salary_data['Revenue'].value_counts())
# Out:
# #### REVENUES ####
# Unknown / Non-Applicable            203
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# -1                                    1
# Name: Revenue, dtype: int64

# %%
# -1 should mean there is no competitor
print(salary_data['Competitors'].nunique(), "unique competitor groups")
print("\n#### COUNTS OF COMPETITORS ####")
print(salary_data['Competitors'].value_counts()[:20])
# Out:
# 128 unique competitor groups
#
# #### COUNTS OF COMPETITORS ####
# -1                                                                                              460
# Novartis, Baxter, Pfizer                                                                         14
# Oak Ridge National Laboratory, National Renewable Energy Lab, Los Alamos National Laboratory     12
# Travelers, Allstate, State Farm                                                                  10
# Roche, GlaxoSmithKline, Novartis                                                                  9
# Battelle, General Atomics, SAIC                                                                   8
# Expedia Group, Orbitz Worldwide, Priceline.com                                                    7
# Pitney Bowes                                                                                      6
# Leidos, CACI International, Booz Allen Hamilton                                                   6
# ...

# %%
competitors = {}
for comp in salary_data['Competitors']:
    if comp == "-1":
        continue
    comp_split = comp.split(', ')
    for one_comp in comp_split:
        if one_comp in competitors.keys():
            competitors[one_comp] += 1
        else:
            competitors[one_comp] = 1
sr_comp = pd.Series(competitors).sort_values(ascending=False)
print(len(sr_comp), "unique competitors")
print("\n#### COUNTS OF COMPETITORS ####")
print(sr_comp)
# Out:
# 302 unique competitors
#
# #### COUNTS OF COMPETITORS ####
# Novartis                          25
# Pfizer                            18
# Los Alamos National Laboratory    15
# GlaxoSmithKline                   15
# Baxter                            14
#                                   ..
# Outcome Health                     1
# Health Media Network               1
# Mesmerize Marketing                1
# Agios Pharmaceuticals              1
# SpotOn                             1
# Length: 302, dtype: int64

# %% [markdown]
# ## Correlations of Numerical Columns

# %%
plt.figure(figsize=(11,6.5))
sns.heatmap(salary_data[['Rating','Founded','hourly','employer_provided','min_salary','max_salary','avg_salary',
        'same_state','age','python_yn','R_yn','spark','aws','excel']].corr(), annot=True, cmap='mako', fmt='.3f')
plt.show()
